# %% [markdown]
# <a href="https://colab.research.google.com/github/Dzy00/CHL5230-Final-Project/blob/main/CHL5230_Final_neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CHL5230 Final Project Neural Networks

# %%
#  CHL5230 final project C CHANGE dataset neural network

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import torch as t
from torch.nn.functional import sigmoid, relu, tanh
from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader
# importing PyTorch modules for building neural networks
from torch.nn import Tanh, Linear, Sequential, Sigmoid, Dropout

from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import confusion_matrix, classification_report
from imblearn.pipeline import Pipeline
from imblearn.under_sampling import TomekLinks, RandomUnderSampler
from imblearn.over_sampling import SMOTE

# warnings.filterwarnings('ignore')

# read the cleaned dataset, so we don't have to rerun the above exploratory and cleaned code
CHANGE_selected = pd.read_csv('CHANGE_selected.csv') #index_col=0


# Define the column that will be used as the target for modeling or analysis
target_column = 'MacroVasc'

# List of columns that contain categorical data
categorical_columns = ['Sex','Any_AntiHTN','HeartFailure_Hx','AtrialFibrillation_Hx',
                       'Smoking_Status','Hypertension_Hx','diabetes']

# List of columns that contain numerical data (excluding categorical columns and the target column)
numerical_columns = [c for c in CHANGE_selected.columns if c not in categorical_columns and c != target_column]


########################################################## neural network
##### prepare data
# Randomly sample 70% of the data for training
train_data = CHANGE_selected.sample(frac = .7, random_state=10)

# Use the remaining 30% for testing
test_data = CHANGE_selected.drop(train_data.index)

# Check the mean of the 'DEATH_EVENT' column in both training and testing data
train_data['MacroVasc'].mean()
test_data['MacroVasc'].mean()

# Data Preparation
# Extract the 'MacroVasc' column as the target variable for training and testing
Y_train = train_data['MacroVasc'].to_numpy()
Y_test = test_data['MacroVasc'].to_numpy()

# Extract the features (excluding 'MacroVasc') for training and testing
X_train = train_data.drop('MacroVasc', axis=1)
X_test = test_data.drop('MacroVasc', axis=1)


##### imputation
# imputate numerical columns with median
num_transformer = SimpleImputer(strategy = 'median')

# impute categorical columns with the most frequent value and encode
cat_transformer = SimpleImputer(strategy = 'most_frequent')

# initialize a column transformer that handels imputation
ct = ColumnTransformer(
    transformers=[
        ('num', num_transformer, numerical_columns),
        ('cat', cat_transformer, categorical_columns)
        ],
    remainder='passthrough')

# Apply the ColumnTransformer to the data
ct.fit(X_train)
ct.fit(X_test)

# transform the data and convert to DataFrame with the new column names
X_train = pd.DataFrame(ct.transform(X_train), columns=ct.get_feature_names_out())
X_test = pd.DataFrame(ct.transform(X_test), columns=ct.get_feature_names_out())

# Standardize the features to have zero mean and unit variance
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# undersample
undersample = RandomUnderSampler(sampling_strategy=0.5)
X_resampled, Y_resampled = undersample.fit_resample(X_train, Y_train)
upsample = SMOTE(sampling_strategy=1)
X_resampled, Y_resampled = upsample.fit_resample(X_resampled, Y_resampled)

# %%
CHANGE_selected.shape
#CHANGE_selected.head
train_data.shape
#X_test.shape
# Out:
# (682760, 16)

# %% [markdown]
# # Implementing the Forward Pass of a Neural Network in PyTorch

# %%
##### Initializing Neural Network Parameters in PyTorch
# Define the number of neurons in the first and second hidden layers
hidden_units_layer_1 = 5
hidden_units_layer_2 = 5

# FIRST LAYER: Define weights and biases for the first layer
W1 = t.randn((15, hidden_units_layer_1), requires_grad=True)
B1 = t.zeros((1, hidden_units_layer_1), requires_grad=True)

# SECOND LAYER: Define weights and biases for the second layer
W2 = t.randn((hidden_units_layer_1, hidden_units_layer_2), requires_grad=True)
B2 = t.zeros((1, hidden_units_layer_2), requires_grad=True)

# THIRD LAYER: Define weights and biases for the output layer
W3 = t.randn((hidden_units_layer_2, 1), requires_grad=True)
B3 = t.zeros((1, 1), requires_grad=True)


# matrix multiplication: @
##### Define the forward pass of the neural network
def forward(input):
    # First hidden layer with tanh activation
    out = tanh(input @ W1 + B1)

    # Second hidden layer with tanh activation
    out = tanh(out @ W2 + B2)

    # Output layer with sigmoid activation (since it's a binary classification problem)
    out = sigmoid(out @ W3 + B3)
    return out

# Convert the training data to PyTorch tensors
X = t.Tensor(X_resampled).type(t.float32)
Y = t.Tensor(Y_resampled).type(t.float32)

# Create a dataset from tensors to be used with DataLoader
train_dataset = TensorDataset(X, Y)

# Define training hyperparameters
epochs = 1000
learning_rate = 0.01
batch_size = 32

# DataLoader provides batches of data for training
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Define the optimizer (Adam) and include all weights and biases
optimizer = Adam([W1, B1, W2, B2, W3, B3], lr=learning_rate)

# Define the loss function (Binary Cross-Entropy Loss)
loss_fn = t.nn.BCELoss()


##### training loop
train_loss_list = []

# Train the model for a specified number of epochs
for epoch in range(epochs):
    # Reduce the learning rate every 500 epochs
    if epoch % 500 == 0:
        learning_rate *= .9

    per_epoch_loss_list = []

    # Iterate over all batches of data
    for batch_idx, (X, Y) in enumerate(train_data_loader):
        # Forward pass: Compute predictions
        probs = forward(X)

        # Compute the loss
        loss = loss_fn(probs.view(-1), Y)

        # Backward pass: Compute gradient and update weights
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Record the loss for this batch
        per_epoch_loss_list.append(loss.item())

    # Record the average loss for this epoch
    train_loss_list.append(sum(per_epoch_loss_list) / len(per_epoch_loss_list))

# Plot the training loss over epochs
plt.plot([i for i in range(len(train_loss_list))], train_loss_list)
plt.xlabel('epochs')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %%
# Evaluate Model Performance on Validation Data
# Disable gradient calculations for evaluation using t.no_grad()
with t.no_grad():
    # Prepare the validation data
    X = t.Tensor(X_test).type(t.float32) # Convert validation features to a PyTorch tensor
    Y = t.Tensor(Y_test).type(t.float32) # Convert validation labels to a PyTorch tensor

    # Calculate predictions on the validation data
    probs = forward(X) # Pass validation data through the trained model
    loss = loss_fn(probs.view(-1), Y) # Compute the loss between predictions and actual labels

    # Print the validation loss
    print(loss.item())

    # Now, evaluate the model on the training data
    X = t.Tensor(X_train).type(t.float32) # Convert training features to a PyTorch tensor
    Y = t.Tensor(Y_train).type(t.float32) # Convert training labels to a PyTorch tensor

    # Calculate predictions on the training data
    probs = forward(X) # Pass training data through the trained model
    loss = loss_fn(probs.view(-1), Y) # Compute the loss between predictions and actual labels

    # Print the training loss
    print(loss.item())
# Out:
# 0.4042932689189911
# 0.4044705629348755

# %% [markdown]
# # prevent overfitting with L2 normalization

# %%
##### use l2 normalization to prevent overfitting
import torch as t
import torch.nn as nn
from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt

# Regularization
# Deep neural networks are prone to overfitting if there is not much data available during training.

# Define hyperparameters
number_of_input_features = 15
number_of_hidden_units = 5
epochs = 100
learning_rate = 0.01
batch_size = 32
landa = 0.01 # Regularization term (lambda)

# Prepare the data
X_train_tensor = t.Tensor(X_resampled).type(t.float32)
Y_train_tensor = t.Tensor(Y_resampled).type(t.float32)

X_test_tensor = t.Tensor(X_test).type(t.float32)
Y_test_tensor = t.Tensor(Y_test).type(t.float32)

train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Define the neural network model with regularization
model = nn.Sequential(
    nn.Linear(number_of_input_features, number_of_hidden_units), # Linear layer for matrix multiplication and bias addition
    nn.Tanh(), # Tanh activation function
    nn.Linear(number_of_hidden_units, 1), # Another linear layer
    nn.Sigmoid() # Sigmoid activation for probability output
)

# Define the optimizer
optimizer = Adam(model.parameters(), lr=learning_rate)

# Define the loss function with Binary Cross-Entropy Loss
loss_fn = nn.BCELoss()

# Lists to store training accuracy, validation accuracy, and training loss over epochs
train_accuracy_list = []
validation_accuracy_list = []
train_loss_list = []

for epoch in range(epochs):
    if epoch % 500 == 0:
        learning_rate *= 0.9 # Learning rate scheduling

    per_epoch_loss_list = []

    for batch_idx, (X, Y) in enumerate(train_data_loader):
        # Forward pass: Compute predictions
        probs = model(X)

        # Adding regularization term for all parameters in the model
        l2_term = sum([(w ** 2).sum() for w in model.parameters()])

        # New loss is the old loss + regularization term
        loss = loss_fn(probs.view(-1), Y) + landa * l2_term

        per_epoch_loss_list.append(loss.item())

        # Backward pass: Compute gradient and update weights
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Evaluate the model on training and validation data
    with t.no_grad():
        # Set the model in eval mode; some layers use this for certain calculations during training
        model.eval()

        # Calculate accuracy on train data
        probs = model(X_train_tensor)
        prediction = (probs >= 0.5).type(t.LongTensor).view(-1)
        train_accuracy = (prediction == Y_train_tensor).type(t.float32).mean().item()

        # Calculate accuracy on validation data
        probs = model(X_test_tensor)
        prediction = (probs >= 0.5).type(t.LongTensor).view(-1)
        validation_accuracy = (prediction == Y_test_tensor).type(t.float32).mean().item()

        # Print accuracy for the current epoch
        print(f'Epoch {epoch}/{epochs} ---> Train Accuracy: {train_accuracy}, Validation Accuracy: {validation_accuracy}')

        # Set the model back to train mode
        model.train()

        # Append accuracy values to lists
        train_accuracy_list.append(train_accuracy)
        validation_accuracy_list.append(validation_accuracy)

    # Calculate and append the average loss for the epoch
    train_loss_list.append(sum(per_epoch_loss_list) / len(per_epoch_loss_list))


# Plot training and validation accuracy over epochs
plt.plot([i for i in range(len(train_accuracy_list))], train_accuracy_list, label="Train")
plt.plot([i for i in range(len(validation_accuracy_list))], validation_accuracy_list, label="Validation")
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()


# confusion matrix
conf_matrix = confusion_matrix(Y_test_tensor, prediction)
class_report = classification_report(Y_test_tensor, prediction)

print("\nClassification Report:")
print(class_report)

sns.heatmap(conf_matrix, cmap='Blues', annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Figure. Confusion Matrix for neural networks with l2 regularization')
plt.show()
# Out:
# Epoch 0/100 ---> Train Accuracy: 0.8279386758804321, Validation Accuracy: 0.7991572618484497
# Epoch 1/100 ---> Train Accuracy: 0.8265190124511719, Validation Accuracy: 0.7671831846237183
# Epoch 2/100 ---> Train Accuracy: 0.8277683258056641, Validation Accuracy: 0.7786522507667542
# Epoch 3/100 ---> Train Accuracy: 0.8243044018745422, Validation Accuracy: 0.7736968994140625
# Epoch 4/100 ---> Train Accuracy: 0.8286768794059753, Validation Accuracy: 0.792062520980835
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.83      0.90    288826
#          1.0       0.06      0.82      0.11      3786
#
#     accuracy                           0.83    292612
#    macro avg       0.53      0.83      0.51    292612
# weighted avg       0.99      0.83      0.89    292612

# %% [markdown]
# # preveting overfitting using dropout

# %%
##### use droppout to prevent overfitting
number_of_input_features = 15 # Number of input features in the dataset

# Reduced number of hidden units to 5 and just using 1 hidden layer
number_of_hidden_units = 5 # Number of hidden units in the neural network
epochs = 100 # Number of training epochs
learning_rate = 0.01 # Learning rate for the optimizer
batch_size = 32 # Number of samples in each training batch
dropout_probablity = 0.6 # Probability of dropping out a neuron in dropout layer

# Convert training and testing data to PyTorch tensors
X_train_tensor = t.Tensor(X_resampled).type(t.float32)
Y_train_tensor = t.Tensor(Y_resampled).type(t.float32)
X_test_tensor = t.Tensor(X_test).type(t.float32)
Y_test_tensor = t.Tensor(Y_test).type(t.float32)

# Create a training dataset and data loader
train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Define the neural network model
model = Sequential(
    Linear(number_of_input_features, number_of_hidden_units), # Linear layer for matrix multiplication and bias addition
    Tanh(), # Add Tanh activation function
    Dropout(dropout_probablity), # Dropout layer to prevent overfitting
    Linear(number_of_hidden_units, 1), # Another linear layer
    Sigmoid() # Sigmoid activation for probability output
)

# Define the optimizer
optimizer = Adam(model.parameters(), lr=learning_rate)

# Define the loss function as Binary Cross-Entropy Loss
loss_fn = t.nn.BCELoss()

train_accuracy_list = [] # List to store training accuracy
validation_accuracy_list = [] # List to store validation accuracy

# Training loop
for epoch in range(epochs):
    if epoch % 500 == 0:
      learning_rate *= 0.9 # Learning rate scheduling

    per_epoch_loss_list = [] # List to store losses for each epoch

    for batch_idx, (X, Y) in enumerate(train_data_loader):
        # Forward pass: Compute predictions
        probs = model(X)

        # Calculate the loss
        loss = loss_fn(probs.view(-1), Y)
        per_epoch_loss_list.append(loss.item())

        # Backward pass: Compute gradients and update weights
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    # Evaluate the model on training and validation data
    with t.no_grad():
        # Set the model in eval mode; some layers use this for certain calculations during training
        model.eval()

        # Calculate accuracy on train data
        probs = model(X_train_tensor)
        prediction = (probs >= 0.5).type(t.LongTensor).view(-1)
        train_accuracy = (prediction == Y_train_tensor).type(t.float32).mean().item()

        # Calculate accuracy on validation data
        probs = model(X_test_tensor)
        prediction = (probs >= 0.5).type(t.LongTensor).view(-1)
        validation_accuracy = (prediction == Y_test_tensor).type(t.float32).mean().item()

        print(f'epoch {epoch}/{epochs} ---> train_accuracy: {train_accuracy}, validation_accuracy: {validation_accuracy}')

        # Set the model back to train mode
        model.train()

        # Append accuracy values to lists
        train_accuracy_list.append(train_accuracy)
        validation_accuracy_list.append(validation_accuracy)


# Plot training and validation accuracy over epochs
plt.plot([i for i in range(len(train_accuracy_list))], train_accuracy_list, label="train")
plt.plot([i for i in range(len(validation_accuracy_list))], validation_accuracy_list, label="validation")
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.show()

# confusion matrix
conf_matrix = confusion_matrix(Y_test_tensor, prediction)
class_report = classification_report(Y_test_tensor, prediction)

print("\nClassification Report:")
print(class_report)

sns.heatmap(conf_matrix, cmap='Blues', annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.81      0.89    288826
#          1.0       0.05      0.86      0.10      3786
#
#     accuracy                           0.81    292612
#    macro avg       0.53      0.83      0.50    292612
# weighted avg       0.99      0.81      0.88    292612

# %% [markdown]
# # prevent overfitting using early stop regularization

# %%
################################################## early stop regularization technique
# Importing necessary libraries
import torch as t
from torch.utils.data import TensorDataset, DataLoader
from torch.nn import Sequential, Linear, Tanh, Sigmoid
from torch.optim import Adam
from torch.nn import BCELoss
import matplotlib.pyplot as plt


# Defining the parameters
number_of_input_features = 15
number_of_hidden_units = 5
epochs = 30
learning_rate = 0.01
batch_size = 32

# Loading and preprocessing the data
X_train_tensor = t.Tensor(X_resampled).type(t.float32)
Y_train_tensor = t.Tensor(Y_resampled).type(t.float32)

X_test_tensor = t.Tensor(X_test).type(t.float32)
Y_test_tensor = t.Tensor(Y_test).type(t.float32)

train_dataset = TensorDataset(X_train_tensor, Y_train_tensor)
train_data_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# Creating a neural network model
model = Sequential(
    Linear(number_of_input_features, number_of_hidden_units),
    Tanh(),
    Linear(number_of_hidden_units, 1),
    Sigmoid()
)

# Setting up the optimizer and loss function
optimizer = Adam(model.parameters(), lr=learning_rate)
loss_fn = BCELoss()

# Lists to store accuracy values during training
train_accuracy_list = []
validation_accuracy_list = []

# Main training loop
for epoch in range(epochs):
    # Learning rate scheduling (optional)
    if epoch % 500 == 0:
        learning_rate *= .9

    per_epoch_loss_list = []

    for batch_idx, (X, Y) in enumerate(train_data_loader):
        probs = model(X)

        # new loss is the old loss + regularization term
        loss = loss_fn(probs.view(-1), Y)

        per_epoch_loss_list.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        with t.no_grad():
            # Calculate accuracy on train data
            model.eval()
            probs = model(X_train_tensor)
            prediction = (probs >= .5).type(t.LongTensor).view(-1)

            train_accuracy = (prediction == Y_train_tensor).type(t.float32).mean().item()

            # Calculate accuracy on validation data
            probs = model(X_test_tensor)
            prediction = (probs > .5).type(t.LongTensor).view(-1)

            validation_accuracy = (prediction == Y_test_tensor).type(t.float32).mean().item()

            print(f'epoch {epoch}/{epochs} ---> train_accuracy : {train_accuracy} , validation_accuracy : {validation_accuracy}')
            model.train()

            train_accuracy_list.append(train_accuracy)
            validation_accuracy_list.append(validation_accuracy)


# Plotting the training and validation accuracy
plt.plot([i for i in range(len(train_accuracy_list))], train_accuracy_list, label="train")
plt.plot([i for i in range(len(validation_accuracy_list))], validation_accuracy_list, label='validation')
plt.legend(loc="upper left")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.show()


# confusion matrix
conf_matrix = confusion_matrix(Y_test_tensor, prediction)
class_report = classification_report(Y_test_tensor, prediction)

print("\nClassification Report:")
print(class_report)

sns.heatmap(conf_matrix, cmap='Blues', annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Figure. Confusion Matrix for neural networks with early stop')
plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# epo
# epoch 25/30 ---> train_accuracy : 0.8328506350517273 , validation_accuracy : 0.8214939832687378
# epoch 25/30 ---> train_accuracy : 0.8327370882034302 , validation_accuracy : 0.8198980093002319
# epoch 25/30 ---> train_accuracy : 0.8328790664672852 , validation_accuracy : 0.819566547870636
# epoch 25/30 ---> train_accuracy : 0.8327654600143433 , validation_accuracy : 0.8193204402923584
# epoch 25/30 ---> train_accuracy : 0.8328506350517273 , validation_accuracy : 0.8191496133804321
# epoch 25/30 ---> train_accuracy : 0.8329358100891113 , validation_accuracy : 0.8187941908836365
# epoch 25/30 ---> train_accuracy : 0.8330777883529663 , validation_accuracy : 0.818271279335022
# epoch 25/30 ---> train_accuracy : 0.8330209851264954 , validation_accuracy : 0.8162583708763123
# epoch 25/30 ---> train_accuracy : 0.8331061601638794 , validation_accuracy : 0.8157696723937988
# epoch 25/30 ---> train_accuracy : 0.8331345915794373 , validation_accuracy : 0.8151305913925171
# epoch 25/30 ---> train_accuracy : 0.8334752917289734 , validation_accuracy : 0.8122941255569458
# epoch 25/30 ---> train_accuracy : 0.8334469199180603 , validation_accuracy : 0.8108826875686646
# epoch 25/30 ---> train_accuracy : 0.8344406485557556 , validation_accuracy : 0.8063374161720276
# epoch 25/30 ---> train_accuracy : 0.8345826268196106 , validation_accuracy : 0.8050148487091064
# epoch 25/30 ---> train_accuracy : 0.8347529768943787 , validation_accuracy : 0.8021714687347412
# epoch 25/30 ---> train_accuracy : 0.8347529768943787 , validation_accuracy : 0.8009240627288818
# epoch 25/30 ---> train_accuracy : 0.8342986702919006 , validation_accuracy : 0.7978380918502808
# epoch 25/30 ---> train_accuracy : 0.8345258235931396 , validation_accuracy : 0.7968060374259949
# epoch 25/30 ---> train_accuracy : 0.8348097801208496 , validation_accuracy : 0.7957055568695068
# epoch 25/30 ---> train_accuracy : 0.8340431451797485 , validation_accuracy : 0.7915806770324707
# epoch 25/30 ---> train_accuracy : 0.8339011669158936 , validation_accuracy : 0.7906715869903564
# epoch 25/30 ---> train_accuracy : 0.8339579701423645 , validation_accuracy : 0.790046215057373
# epoch 25/30 ---> train_accuracy : 0.8340999484062195 , validation_accuracy : 0.7876197695732117
# epoch 25/30 ---> train_accuracy : 0.8345542550086975 , validation_accuracy : 0.7869465351104736
# epoch 25/30 ---> train_accuracy : 0.8346678018569946 , validation_accuracy : 0.7861297726631165
# epoch 25/30 ---> train_accuracy : 0.8342986702919006 , validation_accuracy : 0.7843014001846313
# epoch 25/30 ---> train_accuracy : 0.8342134952545166 , validation_accuracy : 0.7814682722091675
# epoch 25/30 ---> train_accuracy : 0.8341283202171326 , validation_accuracy : 0.7810786962509155
# epoch 25/30 ---> train_accuracy : 0.8340431451797485 , validation_accuracy : 0.7807779312133789
# epoch 25/30 ---> train_accuracy : 0.8339579701423645 , validation_accuracy : 0.7807232737541199
# epoch 25/30 ---> train_accuracy : 0.8339863419532776 , validation_accuracy : 0.7808326482772827
# epoch 25/30 ---> train_accuracy : 0.8339863419532776 , validation_accuracy : 0.7810205817222595
# epoch 25/30 ---> train_accuracy : 0.8339579701423645 , validation_accuracy : 0.7811163067817688
# epoch 25/30 ---> train_accuracy : 0.8340431451797485 , validation_accuracy : 0.7813692092895508
# epoch 25/30 ---> train_accuracy : 0.8340715765953064 , validation_accuracy : 0.7820663452148438
# epoch 25/30 ---> train_accuracy : 0.8340431451797485 , validation_accuracy : 0.7823841571807861
# epoch 25/30 ---> train_accuracy : 0.8342702984809875 , validation_accuracy : 0.7829890847206116
# epoch 25/30 ---> train_accuracy : 0.8343271017074585 , validation_accuracy : 0.7837511897087097
# epoch 25/30 ---> train_accuracy : 0.8343271017074585 , validation_accuracy : 0.7846226692199707
# epoch 25/30 ---> train_accuracy : 0.8343554735183716 , validation_accuracy : 0.7875582575798035
# epoch 25/30 ---> train_accuracy : 0.8350653052330017 , validation_accuracy : 0.7897523045539856
# epoch 25/30 ---> train_accuracy : 0.8349517583847046 , validation_accuracy : 0.7904973030090332
# epoch 25/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.791420042514801
# epoch 25/30 ---> train_accuracy : 0.8352072834968567 , validation_accuracy : 0.7916831970214844
# epoch 25/30 ---> train_accuracy : 0.8352356553077698 , validation_accuracy : 0.7917070984840393
# epoch 25/30 ---> train_accuracy : 0.8351221084594727 , validation_accuracy : 0.7917720675468445
# epoch 25/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.7917583584785461
# epoch 25/30 ---> train_accuracy : 0.8352072834968567 , validation_accuracy : 0.7917618155479431
# epoch 25/30 ---> train_accuracy : 0.8352072834968567 , validation_accuracy : 0.7919497489929199
# epoch 25/30 ---> train_accuracy : 0.8353492617607117 , validation_accuracy : 0.7920351624488831
# epoch 25/30 ---> train_accuracy : 0.8352356553077698 , validation_accuracy : 0.792622983455658
# epoch 25/30 ---> train_accuracy : 0.8353208303451538 , validation_accuracy : 0.7934295535087585
# epoch 25/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.7942702174186707
# epoch 25/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.7969939708709717
# epoch 25/30 ---> train_accuracy : 0.8352072834968567 , validation_accuracy : 0.7981046438217163
# epoch 25/30 ---> train_accuracy : 0.8350936770439148 , validation_accuracy : 0.7990581393241882
# epoch 25/30 ---> train_accuracy : 0.8354911804199219 , validation_accuracy : 0.8018160462379456
# epoch 25/30 ---> train_accuracy : 0.8354344367980957 , validation_accuracy : 0.8034222722053528
# epoch 25/30 ---> train_accuracy : 0.8351221084594727 , validation_accuracy : 0.8038153052330017
# epoch 25/30 ---> train_accuracy : 0.8349517583847046 , validation_accuracy : 0.8044406771659851
# epoch 25/30 ---> train_accuracy : 0.8348381519317627 , validation_accuracy : 0.8043621182441711
# epoch 25/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.8037264347076416
# epoch 25/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.8035077452659607
# epoch 25/30 ---> train_accuracy : 0.8348097801208496 , validation_accuracy : 0.8027148842811584
# epoch 25/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.8021065592765808
# epoch 25/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.8011872172355652
# epoch 25/30 ---> train_accuracy : 0.8353208303451538 , validation_accuracy : 0.8005823493003845
# epoch 25/30 ---> train_accuracy : 0.8353208303451538 , validation_accuracy : 0.8002098202705383
# epoch 25/30 ---> train_accuracy : 0.8352356553077698 , validation_accuracy : 0.7998783588409424
# epoch 25/30 ---> train_accuracy : 0.8353776335716248 , validation_accuracy : 0.7997108697891235
# epoch 25/30 ---> train_accuracy : 0.8353208303451538 , validation_accuracy : 0.7993964552879333
# epoch 25/30 ---> train_accuracy : 0.8351504802703857 , validation_accuracy : 0.7993725538253784
# epoch 25/30 ---> train_accuracy : 0.8351788520812988 , validation_accuracy : 0.799191415309906
# epoch 25/30 ---> train_accuracy : 0.8348381519317627 , validation_accuracy : 0.7982823848724365
# epoch 25/30 ---> train_accuracy : 0.8347246050834656 , validation_accuracy : 0.798576295375824
# epoch 25/30 ---> train_accuracy : 0.8346394300460815 , validation_accuracy : 0.7987539768218994
# epoch 25/30 ---> train_accuracy : 0.8346109986305237 , validation_accuracy : 0.7991093993186951
# epoch 25/30 ---> train_accuracy : 0.8345542550086975 , validation_accuracy : 0.7994853258132935
# epoch 25/30 ---> train_accuracy : 0.8350369334220886 , validation_accuracy : 0.8027148842811584
# epoch 25/30 ---> train_accuracy : 0.8351221084594727 , validation_accuracy : 0.8027695417404175
# epoch 25/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.8028208017349243
# epoch 25/30 ---> train_accuracy : 0.8346678018569946 , validation_accuracy : 0.8029199242591858
# epoch 25/30 ---> train_accuracy : 0.8346109986305237 , validation_accuracy : 0.8032753467559814
# epoch 25/30 ---> train_accuracy : 0.8343838453292847 , validation_accuracy : 0.8031591176986694
# epoch 25/30 ---> train_accuracy : 0.8342986702919006 , validation_accuracy : 0.8034222722053528
# epoch 25/30 ---> train_accuracy : 0.8341851234436035 , validation_accuracy : 0.8035111427307129
# epoch 25/30 ---> train_accuracy : 0.8339579701423645 , validation_accuracy : 0.8039280772209167
# epoch 25/30 ---> train_accuracy : 0.8339295983314514 , validation_accuracy : 0.8039178252220154
# epoch 25/30 ---> train_accuracy : 0.8339011669158936 , validation_accuracy : 0.8038084506988525
# epoch 25/30 ---> train_accuracy : 0.8340431451797485 , validation_accuracy : 0.8037230372428894
# epoch 25/30 ---> train_accuracy : 0.8341283202171326 , validation_accuracy : 0.8038153052330017
# epoch 25/30 ---> train_accuracy : 0.8341851234436035 , validation_accuracy : 0.8037195801734924
# epoch 25/30 ---> train_accuracy : 0.8344406485557556 , validation_accuracy : 0.8034666776657104
# epoch 25/30 ---> train_accuracy : 0.8345258235931396 , validation_accuracy : 0.8031796216964722
# epoch 25/30 ---> train_accuracy : 0.8345542550086975 , validation_accuracy : 0.8029609322547913
# epoch 25/30 ---> train_accuracy : 0.8346109986305237 , validation_accuracy : 0.8025132417678833
# epoch 25/30 ---> train_accuracy : 0.8342134952545166 , validation_accuracy : 0.8002166748046875
# epoch 25/30 ---> train_accuracy : 0.8344690799713135 , validation_accuracy : 0.7998476028442383
# epoch 25/30 ---> train_accuracy : 0.8344690799713135 , validation_accuracy : 0.8012009263038635
# epoch 25/30 ---> train_accuracy : 0.8345542550086975 , validation_accuracy : 0.8011599183082581
# epoch 25/30 ---> train_accuracy : 0.8346678018569946 , validation_accuracy : 0.8010915517807007
# epoch 25/30 ---> train_accuracy : 0.8348097801208496 , validation_accuracy : 0.8008420467376709
# epoch 25/30 ---> train_accuracy : 0.8348097801208496 , validation_accuracy : 0.8006370067596436
# epoch 25/30 ---> train_accuracy : 0.8350653052330017 , validation_accuracy : 0.8003773093223572
# epoch 25/30 ---> train_accuracy : 0.8344122767448425 , validation_accuracy : 0.7981696128845215
# epoch 25/30 ---> train_accuracy : 0.8347246050834656 , validation_accuracy : 0.7963138818740845
# epoch 25/30 ---> train_accuracy : 0.8346109986305237 , validation_accuracy : 0.7957192659378052
# epoch 25/30 ---> train_accuracy : 0.8344122767448425 , validation_accuracy : 0.795151948928833
# epoch 25/30 ---> train_accuracy : 0.8343271017074585 , validation_accuracy : 0.7950596809387207
# epoch 25/30 ---> train_accuracy : 0.8344122767448425 , validation_accuracy : 0.7951861023902893
# epoch 25/30 ---> train_accuracy : 0.8343271017074585 , validation_accuracy : 0.7953125834465027
# epoch 25/30 ---> train_accuracy : 0.8344122767448425 , validation_accuracy : 0.7935081124305725
# epoch 25/30 ---> train_accuracy : 0.8345826268196106 , validation_accuracy : 0.7957295179367065
# epoch 25/30 ---> train_accuracy : 0.8346678018569946 , validation_accuracy : 0.7961703538894653
# epoch 25/30 ---> train_accuracy : 0.8346678018569946 , validation_accuracy : 0.7978312373161316
# epoch 25/30 ---> train_accuracy : 0.8346961736679077 , validation_accuracy : 0.7983096837997437
# epoch 25/30 ---> train_accuracy : 0.8345258235931396 , validation_accuracy : 0.7986924648284912
# epoch 25/30 ---> train_accuracy : 0.8345542550086975 , validation_accuracy : 0.7994648218154907
# epoch 25/30 ---> train_accuracy : 0.8349517583847046 , validation_accuracy : 0.8019800782203674
# epoch 25/30 ---> train_accuracy : 0.8349233269691467 , validation_accuracy : 0.8023013472557068
# epoch 25/30 ---> train_accuracy : 0.8349233269691467 , validation_accuracy : 0.8024312257766724
# epoch 25/30 ---> train_accuracy : 0.8348381519317627 , validation_accuracy : 0.8028789162635803
# epoch 25/30 ---> train_accuracy : 0.8347529768943787 , validation_accuracy : 0.8032206296920776
# epoch 25/30 ---> train_accuracy : 0.8346678018569946 , validation_accuracy : 0.803459882736206
# epoch 25/30 ---> train_accuracy : 0.8346961736679077 , validation_accuracy : 0.8036034107208252
# epoch 25/30 ---> train_accuracy : 0.8346961736679077 , validation_accuracy : 0.8036307692527771
# epoch 25/30 ---> train_accuracy : 0.8347529768943787 , validation_accuracy : 0.8038153052330017
# epoch 25/30 ---> train_accuracy : 0.8347813487052917 , validation_accuracy : 0.8043005466461182
# epoch 25/30 ---> train_accuracy : 0.8348949551582336 , validation_accuracy : 0.8042458891868591
# epoch 25/30 ---> train_accuracy : 0.8348381519317627 , validation_accuracy : 0.8044201731681824
# epoch 25/30 ---> train_accuracy : 0.8350936770439148 , validation_accuracy : 0.8067611455917358
# epoch 25/30 ---> train_accuracy : 0.8351788520812988 , validation_accuracy : 0.8071302771568298
# epoch 25/30 ---> train_accuracy : 0.8350369334220886 , validation_accuracy : 0.8075027465820312
# epoch 25/30 ---> train_accuracy : 0.8348097801208496 , validation_accuracy : 0.8080700635910034
# epoch 25/30 ---> train_accuracy : 0.8348381519317627 , validation_accuracy : 0.8084254860877991
# epoch 25/30 ---> train_accuracy : 0.8346678018569946 , validation_accuracy : 0.8085792660713196
# epoch 25/30 ---> train_accuracy : 0.8348097801208496 , validation_accuracy : 0.8087193965911865
# epoch 25/30 ---> train_accuracy : 0.8347813487052917 , validation_accuracy : 0.8085690140724182
# epoch 25/30 ---> train_accuracy : 0.8351504802703857 , validation_accuracy : 0.8081794381141663
# epoch 25/30 ---> train_accuracy : 0.8354060053825378 , validation_accuracy : 0.8078035116195679
# epoch 25/30 ---> train_accuracy : 0.8354628086090088 , validation_accuracy : 0.8075437545776367
# epoch 25/30 ---> train_accuracy : 0.8355763554573059 , validation_accuracy : 0.8073592185974121
# epoch 25/30 ---> train_accuracy : 0.8352072834968567 , validation_accuracy : 0.8051036596298218
# epoch 25/30 ---> train_accuracy : 0.8353776335716248 , validation_accuracy : 0.8045329451560974
# epoch 25/30 ---> train_accuracy : 0.8355763554573059 , validation_accuracy : 0.8039929866790771
# epoch 25/30 ---> train_accuracy : 0.8355479836463928 , validation_accuracy : 0.8035658001899719
# epoch 25/30 ---> train_accuracy : 0.8356899619102478 , validation_accuracy : 0.8026841282844543
# epoch 25/30 ---> train_accuracy : 0.8350653052330017 , validation_accuracy : 0.799639105796814
# epoch 25/30 ---> train_accuracy : 0.8355196118354797 , validation_accuracy : 0.7987198233604431
# epoch 25/30 ---> train_accuracy : 0.8357751369476318 , validation_accuracy : 0.7987608313560486
# epoch 25/30 ---> train_accuracy : 0.8358319401741028 , validation_accuracy : 0.7982345223426819
# epoch 25/30 ---> train_accuracy : 0.835973858833313 , validation_accuracy : 0.7962318658828735
# epoch 25/30 ---> train_accuracy : 0.8359171152114868 , validation_accuracy : 0.7961942553520203
# epoch 25/30 ---> train_accuracy : 0.835888683795929 , validation_accuracy : 0.7961088418960571
# epoch 25/30 ---> train_accuracy : 0.835746705532074 , validation_accuracy : 0.7964369058609009
# epoch 25/30 ---> train_accuracy : 0.8358603119850159 , validation_accuracy : 0.796501874923706
# epoch 25/30 ---> train_accuracy : 0.8359454870223999 , validation_accuracy : 0.7964403629302979
# epoch 25/30 ---> train_accuracy : 0.8360022902488708 , validation_accuracy : 0.796662449836731
# epoch 25/30 ---> train_accuracy : 0.8359171152114868 , validation_accuracy : 0.7968606948852539
# epoch 25/30 ---> train_accuracy : 0.835888683795929 , validation_accuracy : 0.799249529838562
# epoch 25/30 ---> train_accuracy : 0.8358603119850159 , validation_accuracy : 0.7995160818099976
# epoch 25/30 ---> train_accuracy : 0.8359454870223999 , validation_accuracy : 0.7999432682991028
# epoch 25/30 ---> train_accuracy : 0.8360306620597839 , validation_accuracy : 0.8000389337539673
# epoch 25/30 ---> train_accuracy : 0.835888683795929 , validation_accuracy : 0.800257682800293
# epoch 25/30 ---> train_accuracy : 0.836059033870697 , validation_accuracy : 0.8003568053245544
# epoch 25/30 ---> train_accuracy : 0.836115837097168 , validation_accuracy : 0.800541341304779
# epoch 25/30 ---> train_accuracy : 0.836115837097168 , validation_accuracy : 0.8008865118026733
# epoch 25/30 ---> train_accuracy : 0.836115837097168 , validation_accuracy : 0.8009753823280334
# epoch 25/30 ---> train_accuracy : 0.8360022902488708 , validation_accuracy : 0.800930917263031
# epoch 25/30 ---> train_accuracy : 0.835973858833313 , validation_accuracy : 0
30 ---> train_accuracy : 0.8354628086090088 , validation_accuracy : 0.7802311778068542
# epoch 25/30 ---> train_accuracy : 0.8342419266700745 , validation_accuracy : 0.776290774345398
# epoch 25/30 ---> train_accuracy : 0.8341567516326904 , validation_accuracy : 0.7757508158683777
# epoch 25/30 ---> train_accuracy : 0.8341567516326904 , validation_accuracy : 0.7755560278892517
# epoch 25/30 ---> train_accuracy : 0.8339011669158936 , validation_accuracy : 0.7745683789253235
# epoch 25/30 ---> train_accuracy : 0.8338444232940674 , validation_accuracy : 0.7740728259086609
# epoch 25/30 ---> train_accuracy : 0.8337592482566833 , validation_accuracy : 0.7737174034118652
# epoch 25/30 ---> train_accuracy : 0.8338444232940674 , validation_accuracy : 0.7732731103897095
# epoch 25/30 ---> train_accuracy : 0.8337876200675964 , validation_accuracy : 0.7730475664138794
# epoch 25/30 ---> train_accuracy : 0.8336740732192993 , validation_accuracy : 0.772671639919281
# epoch 25/30 ---> train_accuracy : 0.8335036635398865 , validation_accuracy : 0.7722684144973755
# epoch 25/30 ---> train_accuracy : 0.8333617448806763 , validation_accuracy : 0.7716293334960938
# epoch 25/30 ---> train_accuracy : 0.8327087163925171 , validation_accuracy : 0.7681708335876465
# epoch 25/30 ---> train_accuracy : 0.8323679566383362 , validation_accuracy : 0.7667901515960693
# epoch 25/30 ---> train_accuracy : 0.8324247598648071 , validation_accuracy : 0.7659186720848083
# epoch 25/30 ---> train_accuracy : 0.8322544097900391 , validation_accuracy : 0.7649071216583252
# epoch 25/30 ---> train_accuracy : 0.8323395848274231 , validation_accuracy : 0.7641381621360779
# epoch 25/30 ---> train_accuracy : 0.831658124923706 , validation_accuracy : 0.7607958912849426
# epoch 25/30 ---> train_accuracy : 0.8302952647209167 , validation_accuracy : 0.7586086988449097
# epoch 25/30 ---> train_accuracy : 0.8303520679473877 , validation_accuracy : 0.7578397393226624
# epoch 25/30 ---> train_accuracy : 0.8303236961364746 , validation_accuracy : 0.757269024848938
# epoch 25/30 ---> train_accuracy : 0.8304088711738586 , validation_accuracy : 0.7567768692970276
# epoch 25/30 ---> train_accuracy : 0.8303236961364746 , validation_accuracy : 0.7564043998718262
# epoch 25/30 ---> train_accuracy : 0.8302668929100037 , validation_accuracy : 0.7562437653541565
# epoch 25/30 ---> train_accuracy : 0.8303520679473877 , validation_accuracy : 0.7557653188705444
# epoch 25/30 ---> train_accuracy : 0.8302100896835327 , validation_accuracy : 0.7553005218505859
# epoch 25/30 ---> train_accuracy : 0.8301533460617065 , validation_accuracy : 0.7547879219055176
# epoch 25/30 ---> train_accuracy : 0.8296706676483154 , validation_accuracy : 0.7527784109115601
# epoch 25/30 ---> train_accuracy : 0.8289040327072144 , validation_accuracy : 0.749131977558136
# epoch 25/30 ---> train_accuracy : 0.8288188576698303 , validation_accuracy : 0.7487970590591431
# epoch 25/30 ---> train_accuracy : 0.8286485075950623 , validation_accuracy : 0.7486056685447693
# epoch 25/30 ---> train_accuracy : 0.8285633325576782 , validation_accuracy : 0.7483903765678406
# epoch 25/30 ---> train_accuracy : 0.8285349011421204 , validation_accuracy : 0.7483459115028381
# epoch 25/30 ---> train_accuracy : 0.8284497261047363 , validation_accuracy : 0.7483766674995422
# epoch 25/30 ---> train_accuracy : 0.8286768794059753 , validation_accuracy : 0.748513400554657
# epoch 25/30 ---> train_accuracy : 0.8286768794059753 , validation_accuracy : 0.748397171497345
# epoch 25/30 ---> train_accuracy : 0.8287336826324463 , validation_accuracy : 0.7483049035072327
# epoch 25/30 ---> train_accuracy : 0.8287336826324463 , validation_accuracy : 0.7482946515083313
# epoch 25/30 ---> train_accuracy : 0.8286485075950623 , validation_accuracy : 0.748762845993042
# epoch 25/30 ---> train_accuracy : 0.8286485075950623 , validation_accuracy : 0.7493028044700623
# epoch 25/30 ---> train_accuracy : 0.8293867111206055 , validation_accuracy : 0.7528877854347229
# epoch 25/30 ---> train_accuracy : 0.8295002579689026 , validation_accuracy : 0.7536977529525757
# epoch 25/30 ---> train_accuracy : 0.8294718861579895 , validation_accuracy : 0.7544769048690796
# epoch 25/30 ---> train_accuracy : 0.8297558426856995 , validation_accuracy : 0.7555773258209229
# epoch 25/30 ---> train_accuracy : 0.8312890529632568 , validation_accuracy : 0.7605292797088623
# epoch 25/30 ---> train_accuracy : 0.8316013813018799 , validation_accuracy : 0.7617220282554626
# epoch 25/30 ---> train_accuracy : 0.831714928150177 , validation_accuracy : 0.7630616426467896
# epoch 25/30 ---> train_accuracy : 0.831856906414032 , validation_accuracy : 0.7641040086746216
# epoch 25/30 ---> train_accuracy : 0.8330209851264954 , validation_accuracy : 0.7673711180686951
# epoch 25/30 ---> train_accuracy : 0.8331913948059082 , validation_accuracy : 0.7681503295898438
# epoch 25/30 ---> train_accuracy : 0.8332765698432922 , validation_accuracy : 0.7692610025405884
# epoch 25/30 ---> train_accuracy : 0.8340715765953064 , validation_accuracy : 0.771492600440979
# epoch 25/30 ---> train_accuracy : 0.8342134952545166 , validation_accuracy : 0.7723435759544373
# epoch 25/30 ---> train_accuracy : 0.8347529768943787 , validation_accuracy : 0.7760823369026184
# epoch 25/30 ---> train_accuracy : 0.8347813487052917 , validation_accuracy : 0.7774014472961426
# epoch 25/30 ---> train_accuracy : 0.8356047868728638 , validation_accuracy : 0.781348705291748
# epoch 25/30 ---> train_accuracy : 0.8357751369476318 , validation_accuracy : 0.7840621471405029
# epoch 25/30 ---> train_accuracy : 0.835746705532074 , validation_accuracy : 0.7874386310577393
# epoch 25/30 ---> train_accuracy : 0.835888683795929 , validation_accuracy : 0.7888740301132202
# epoch 25/30 ---> train_accuracy : 0.8356615304946899 , validation_accuracy : 0.7921240329742432
# epoch 25/30 ---> train_accuracy : 0.835746705532074 , validation_accuracy : 0.7944547533988953
# epoch 25/30 ---> train_accuracy : 0.8357751369476318 , validation_accuracy : 0.7967923283576965
# epoch 25/30 ---> train_accuracy : 0.8354060053825378 , validation_accuracy : 0.7976535558700562
# epoch 25/30 ---> train_accuracy : 0.8353208303451538 , validation_accuracy : 0.8007053732872009
# epoch 25/30 ---> train_accuracy : 0.8352072834968567 , validation_accuracy : 0.8017852902412415
# epoch 25/30 ---> train_accuracy : 0.8351504802703857 , validation_accuracy : 0.8054112792015076
# epoch 25/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.8057769536972046
# epoch 25/30 ---> train_accuracy : 0.8354060053825378 , validation_accuracy : 0.8036820292472839
# epoch 25/30 ---> train_accuracy : 0.8354060053825378 , validation_accuracy : 0.8033949136734009
# epoch 25/30 ---> train_accuracy : 0.8351788520812988 , validation_accuracy : 0.8017169237136841
# epoch 25/30 ---> train_accuracy : 0.8352640271186829 , validation_accuracy : 0.8017032742500305
# epoch 25/30 ---> train_accuracy : 0.8354628086090088 , validation_accuracy : 0.8015392422676086
# epoch 25/30 ---> train_accuracy : 0.8354911804199219 , validation_accuracy : 0.8011086583137512
# epoch 25/30 ---> train_accuracy : 0.8354911804199219 , validation_accuracy : 0.8008386492729187
# epoch 25/30 ---> train_accuracy : 0.8349517583847046 , validation_accuracy : 0.7989453673362732
# epoch 25/30 ---> train_accuracy : 0.8356899619102478 , validation_accuracy : 0.8011394143104553
# epoch 25/30 ---> train_accuracy : 0.8356047868728638 , validation_accuracy : 0.8015528917312622
# epoch 25/30 ---> train_accuracy : 0.8359454870223999 , validation_accuracy : 0.8024824857711792
# epoch 25/30 ---> train_accuracy : 0.8357183337211609 , validation_accuracy : 0.8039349317550659
# epoch 25/30 ---> train_accuracy : 0.8354344367980957 , validation_accuracy : 0.807639479637146
# epoch 25/30 ---> train_accuracy : 0.8354060053825378 , validation_accuracy : 0.8083161115646362
# epoch 25/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.8101854920387268
# epoch 25/30 ---> train_accuracy : 0.8348097801208496 , validation_accuracy : 0.810417890548706
# epoch 25/30 ---> train_accuracy : 0.8348949551582336 , validation_accuracy : 0.8104144930839539
# epoch 25/30 ---> train_accuracy : 0.8351788520812988 , validation_accuracy : 0.8097036480903625
# epoch 25/30 ---> train_accuracy : 0.8355763554573059 , validation_accuracy : 0.8083298206329346
# epoch 25/30 ---> train_accuracy : 0.8360022902488708 , validation_accuracy : 0.8056094646453857
# epoch 25/30 ---> train_accuracy : 0.836201012134552 , validation_accuracy : 0.8046901822090149
# epoch 25/30 ---> train_accuracy : 0.836144208908081 , validation_accuracy : 0.8045090436935425
# epoch 25/30 ---> train_accuracy : 0.8362294435501099 , validation_accuracy : 0.8042219877243042
# epoch 25/30 ---> train_accuracy : 0.836115837097168 , validation_accuracy : 0.8012863397598267
# epoch 25/30 ---> train_accuracy : 0.8363997936248779 , validation_accuracy : 0.7998476028442383
# epoch 25/30 ---> train_accuracy : 0.8357751369476318 , validation_accuracy : 0.7951622009277344
# epoch 25/30 ---> train_accuracy : 0.8356331586837769 , validation_accuracy : 0.7939524054527283
# epoch 25/30 ---> train_accuracy : 0.8356615304946899 , validation_accuracy : 0.7933953404426575
# epoch 25/30 ---> train_accuracy : 0.8354911804199219 , validation_accuracy : 0.7932620644569397
# epoch 25/30 ---> train_accuracy : 0.8354911804199219 , validation_accuracy : 0.7928758859634399
# epoch 25/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.792404294013977
# epoch 25/30 ---> train_accuracy : 0.8354911804199219 , validation_accuracy : 0.7896907925605774
# epoch 25/30 ---> train_accuracy : 0.8356331586837769 , validation_accuracy : 0.7889560461044312
# epoch 25/30 ---> train_accuracy : 0.8355196118354797 , validation_accuracy : 0.7883784770965576
# epoch 25/30 ---> train_accuracy : 0.8353492617607117 , validation_accuracy : 0.7879717946052551
# epoch 25/30 ---> train_accuracy : 0.8356331586837769 , validation_accuracy : 0.7875787615776062
# epoch 25/30 ---> train_accuracy : 0.8356047868728638 , validation_accuracy : 0.7875446081161499
# epoch 25/30 ---> train_accuracy : 0.8355479836463928 , validation_accuracy : 0.7855214476585388
# epoch 25/30 ---> train_accuracy : 0.8355763554573059 , validation_accuracy : 0.7853608131408691
# epoch 25/30 ---> train_accuracy : 0.8355763554573059 , validation_accuracy : 0.7851728796958923
# epoch 25/30 ---> train_accuracy : 0.8358319401741028 , validation_accuracy : 0.785606861114502
# epoch 25/30 ---> train_accuracy : 0.8357751369476318 , validation_accuracy : 0.787746250629425
# epoch 25/30 ---> train_accuracy : 0.835746705532074 , validation_accuracy : 0.7877565026283264
# epoch 25/30 ---> train_accuracy : 0.8356331586837769 , validation_accuracy : 0.7855077981948853
# epoch 25/30 ---> train_accuracy : 0.8357751369476318 , validation_accuracy : 0.7856718301773071
# epoch 25/30 ---> train_accuracy : 0.8358319401741028 , validation_accuracy : 0.785948634147644
# epoch 25/30 ---> train_accuracy : 0.835746705532074 , validation_accuracy : 0.7882246971130371
# epoch 25/30 ---> train_accuracy : 0.8355763554573059 , validation_accuracy : 0.7884809970855713
# epoch 25/30 ---> train_accuracy : 0.8355479836463928 , validation_accuracy : 0.7888500690460205
# epoch 25/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.7893114686012268
# epoch 25/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.7897078990936279
# epoch 25/30 ---> train_accuracy : 0.8351221084594727 , validation_accuracy : 0.790015459060669
# epoch 25/30 ---> train_accuracy : 0.8350369334220886 , validation_accuracy : 0.7903401255607605
# epoch 25/30 ---> train_accuracy : 0.8350369334220886 , validation_accuracy : 0.7905451655387878
# epoch 25/30 ---> train_accuracy : 0.8350936770439148 , validation_accuracy : 0.7909108400344849
# epoch 25/30 ---> train_accuracy : 0.8350085020065308 , validation_accuracy : 0.793467104434967
# epoch 25/30 ---> train_accuracy : 0.8348381519317627 , validation_accuracy : 0.7938327789306641
# epoch 25/30 ---> train_accuracy : 0.8351221084594727 , validation_accuracy : 0.7956919074058533
# epoch 25/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.7962592244148254
# epoch 25/30 ---> train_accuracy : 0.8350936770439148 , validation_accuracy : 0.7965155243873596
# epoch 25/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.799389660358429
# epoch 25/30 ---> train_accuracy : 0.8350653052330017 , validation_accuracy : 0.8003020882606506
# epoch 25/30 ---> train_accuracy : 0.8346961736679077 , validation_accuracy : 0.8010266423225403
# epoch 25/30 ---> train_accuracy : 0.8348097801208496 , validation_accuracy : 0.8016759157180786
# epoch 25/30 ---> train_accuracy : 0.8350085020065308 , validation_accuracy : 0.8023218512535095
# epoch 25/30 ---> train_accuracy : 0.8356047868728638 , validation_accuracy : 0.8049806356430054
# epoch 25/30 ---> train_accuracy : 0.8352640271186829 , validation_accuracy : 0.8056675791740417
# epoch 25/30 ---> train_accuracy : 0.8349517583847046 , validation_accuracy : 0.8067440986633301
# epoch 25/30 ---> train_accuracy : 0.8349233269691467 , validation_accuracy : 0.8076804876327515
# epoch 25/30 ---> train_accuracy : 0.8346961736679077 , validation_accuracy : 0.8081725835800171
# ...
# epoch 29/30 ---> train_accuracy : 0.8348665237426758 , validation_accuracy : 0.781061589717865
# epoch 29/30 ---> train_accuracy : 0.8349233269691467 , validation_accuracy : 0.780754029750824
# epoch 29/30 ---> train_accuracy : 0.8352640271186829 , validation_accuracy : 0.7802345752716064
# epoch 29/30 ---> train_accuracy : 0.8352356553077698 , validation_accuracy : 0.7795920968055725
# epoch 29/30 ---> train_accuracy : 0.8351221084594727 , validation_accuracy : 0.7788470983505249
# epoch 29/30 ---> train_accuracy : 0.8351221084594727 , validation_accuracy : 0.7786317467689514
# epoch 29/30 ---> train_accuracy : 0.8349517583847046 , validation_accuracy : 0.7783036828041077
# epoch 29/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.777890145778656
# epoch 29/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.7776133418083191
# epoch 29/30 ---> train_accuracy : 0.8350369334220886 , validation_accuracy : 0.7775176763534546
# epoch 29/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.7772408723831177
# epoch 29/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.7768957018852234
# epoch 29/30 ---> train_accuracy : 0.8351504802703857 , validation_accuracy : 0.7766633033752441
# epoch 29/30 ---> train_accuracy : 0.8343838453292847 , validation_accuracy : 0.7744213938713074
# epoch 29/30 ---> train_accuracy : 0.8344122767448425 , validation_accuracy : 0.7744385004043579
# epoch 29/30 ---> train_accuracy : 0.8351504802703857 , validation_accuracy : 0.7767999768257141
# epoch 29/30 ---> train_accuracy : 0.8352072834968567 , validation_accuracy : 0.7770460247993469
# epoch 29/30 ---> train_accuracy : 0.8351221084594727 , validation_accuracy : 0.7776680588722229
# epoch 29/30 ---> train_accuracy : 0.8353776335716248 , validation_accuracy : 0.7792469263076782
# epoch 29/30 ---> train_accuracy : 0.8353776335716248 , validation_accuracy : 0.7797595262527466
# epoch 29/30 ---> train_accuracy : 0.8349801301956177 , validation_accuracy : 0.7802004218101501
# epoch 29/30 ---> train_accuracy : 0.8350653052330017 , validation_accuracy : 0.7825687527656555
# epoch 29/30 ---> train_accuracy : 0.8349517583847046 , validation_accuracy : 0.7831975221633911
# epoch 29/30 ---> train_accuracy : 0.8349517583847046 , validation_accuracy : 0.7840484976768494
# epoch 29/30 ---> train_accuracy : 0.8350936770439148 , validation_accuracy : 0.7846875786781311
# epoch 29/30 ---> train_accuracy : 0.8348665237426758 , validation_accuracy : 0.7872233390808105
# epoch 29/30 ---> train_accuracy : 0.8348097801208496 , validation_accuracy : 0.7877599000930786
# epoch 29/30 ---> train_accuracy : 0.8349233269691467 , validation_accuracy : 0.7882691025733948
# epoch 29/30 ---> train_accuracy : 0.8348381519317627 , validation_accuracy : 0.7887919545173645
# epoch 29/30 ---> train_accuracy : 0.8346394300460815 , validation_accuracy : 0.7892362475395203
# epoch 29/30 ---> train_accuracy : 0.8346961736679077 , validation_accuracy : 0.7896121740341187
# epoch 29/30 ---> train_accuracy : 0.8352640271186829 , validation_accuracy : 0.7921547889709473
# epoch 29/30 ---> train_accuracy : 0.8358319401741028 , validation_accuracy : 0.7938772439956665
# epoch 29/30 ---> train_accuracy : 0.8355196118354797 , validation_accuracy : 0.
30 ---> train_accuracy : 0.8357751369476318 , validation_accuracy : 0.7904767990112305
# epoch 29/30 ---> train_accuracy : 0.8356899619102478 , validation_accuracy : 0.7909005880355835
# epoch 29/30 ---> train_accuracy : 0.8355763554573059 , validation_accuracy : 0.7914474010467529
# epoch 29/30 ---> train_accuracy : 0.8356331586837769 , validation_accuracy : 0.7917002439498901
# epoch 29/30 ---> train_accuracy : 0.8356331586837769 , validation_accuracy : 0.7918916344642639
# epoch 29/30 ---> train_accuracy : 0.835746705532074 , validation_accuracy : 0.7923871874809265
# epoch 29/30 ---> train_accuracy : 0.8357751369476318 , validation_accuracy : 0.7926195859909058
# epoch 29/30 ---> train_accuracy : 0.8357183337211609 , validation_accuracy : 0.7928280234336853
# epoch 29/30 ---> train_accuracy : 0.8360874652862549 , validation_accuracy : 0.7941061854362488
# epoch 29/30 ---> train_accuracy : 0.8360306620597839 , validation_accuracy : 0.7942155599594116
# epoch 29/30 ---> train_accuracy : 0.8358603119850159 , validation_accuracy : 0.7942497134208679
# epoch 29/30 ---> train_accuracy : 0.8358603119850159 , validation_accuracy : 0.7940959334373474
# epoch 29/30 ---> train_accuracy : 0.8353208303451538 , validation_accuracy : 0.7956337928771973
# epoch 29/30 ---> train_accuracy : 0.8354344367980957 , validation_accuracy : 0.7957055568695068
# epoch 29/30 ---> train_accuracy : 0.8353776335716248 , validation_accuracy : 0.7953979969024658
# epoch 29/30 ---> train_accuracy : 0.8353776335716248 , validation_accuracy : 0.7958661913871765
# epoch 29/30 ---> train_accuracy : 0.8353208303451538 , validation_accuracy : 0.7960507273674011
# epoch 29/30 ---> train_accuracy : 0.8354628086090088 , validation_accuracy : 0.7967820763587952
# epoch 29/30 ---> train_accuracy : 0.8353776335716248 , validation_accuracy : 0.796778678894043
# epoch 29/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.7970998883247375
# epoch 29/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.7978244423866272
# epoch 29/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.79877108335495
# epoch 29/30 ---> train_accuracy : 0.8351504802703857 , validation_accuracy : 0.7998749017715454
# epoch 29/30 ---> train_accuracy : 0.835973858833313 , validation_accuracy : 0.8028720617294312
# epoch 29/30 ---> train_accuracy : 0.8359171152114868 , validation_accuracy : 0.8037230372428894
# epoch 29/30 ---> train_accuracy : 0.835888683795929 , validation_accuracy : 0.8057427406311035
# epoch 29/30 ---> train_accuracy : 0.8356899619102478 , validation_accuracy : 0.8064057230949402
# epoch 29/30 ---> train_accuracy : 0.8358319401741028 , validation_accuracy : 0.8089381456375122
# epoch 29/30 ---> train_accuracy : 0.8356047868728638 , validation_accuracy : 0.8099189400672913
# epoch 29/30 ---> train_accuracy : 0.8354628086090088 , validation_accuracy : 0.8105272650718689
# epoch 29/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.8109168410301208
# epoch 29/30 ---> train_accuracy : 0.8353492617607117 , validation_accuracy : 0.8113542795181274
# epoch 29/30 ---> train_accuracy : 0.8353208303451538 , validation_accuracy : 0.8114396929740906
# epoch 29/30 ---> train_accuracy : 0.8351504802703857 , validation_accuracy : 0.8115149140357971
# epoch 29/30 ---> train_accuracy : 0.8352356553077698 , validation_accuracy : 0.8118361234664917
# epoch 29/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.8143138289451599
# epoch 29/30 ---> train_accuracy : 0.8352072834968567 , validation_accuracy : 0.8156706094741821
# epoch 29/30 ---> train_accuracy : 0.8353492617607117 , validation_accuracy : 0.8158106803894043
# epoch 29/30 ---> train_accuracy : 0.8352640271186829 , validation_accuracy : 0.8156090378761292
# epoch 29/30 ---> train_accuracy : 0.8353776335716248 , validation_accuracy : 0.8155714869499207
# epoch 29/30 ---> train_accuracy : 0.8352924585342407 , validation_accuracy : 0.8147991299629211
# epoch 29/30 ---> train_accuracy : 0.8353492617607117 , validation_accuracy : 0.8136610984802246
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.81      0.90    288826
#          1.0       0.06      0.85      0.11      3786
#
#     accuracy                           0.81    292612
#    macro avg       0.53      0.83      0.50    292612
# weighted avg       0.99      0.81      0.89    292612
